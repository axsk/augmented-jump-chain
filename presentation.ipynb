# %%
# %autoreload 2
import sys
sys.path.append('src')
import sqra
import numpy as np
import ajc
import ajcs
from scipy.linalg import expm
import scipy.sparse.linalg as spl
import matplotlib.pyplot as plt

# %%
Q = np.array([[-2,1,1],[1,-2,1],[1, 0, -1]])
from src.gillespie import gillespie
xs, ts = gillespie(Q, 0, 5)

# %%
c = "black"
c2 = "blue"
for i in range(len(xs)-1):
    plt.plot([ts[i], ts[i+1]], [xs[i], xs[i]], color=c)
    plt.plot([ts[i+1], ts[i+1]], [xs[i], xs[i+1]], linestyle="dashed", color=c)
    #plt.plot([ts[i], ts[i+1]], [xs[i], xs[i+1]], color=c2)
    #plt.arrow(ts[i], xs[i], ts[i+1]-ts[i], xs[i+1]-xs[i], width=0.01, length_includes_head=True, color=c2, head_width=0.1)
plt.plot()
plt.yticks([0,1,2],[1,2,3])
plt.ylabel("X")
plt.xlabel("t")
plt.savefig("slides/traj.pdf")

# %%
plt.imshow(expm(0.5*Q))
plt.colorbar()
plt.clim([0,.8])
plt.yticks([0,1,2], [1,2,3])
plt.xticks([0,1,2], [1,2,3])
plt.savefig("slides/p.pdf")

# %%
[Q for i in range(2)]
# Out:
# [array([[-2,  1,  1],
#         [ 1, -2,  1],
#         [ 1,  0, -1]]),
#  array([[-2,  1,  1],
#         [ 1, -2,  1],
#         [ 1,  0, -1]])]

# %%
j=ajcs.AJCS([Q for i in range(10)], np.repeat(0.1, 10))
#plt.imshow(j.km.todense())
x0 = np.array([0,0,1])
j.jump(x0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-ddad736d3e32> in <module>
#       2 #plt.imshow(j.km.todense())
#       3 x0 = np.array([0,0,1])
# ----> 4 j.jump(x0)
#
# ~/Documents/code/augjuc/src/ajcs.py in jump(self, p)
#      34
#      35     def jump(self, p):
# ---> 36         return np.reshape(p.flatten() @ self.km, p.shape)
#      37
#      38     def geiger(self, p, n=100):
#
# /usr/local/lib/python3.8/site-packages/scipy/sparse/base.py in __rmatmul__(self, other)
#     564             raise ValueError("Scalar operands are not allowed, "
#     565                              "use '*' instead")
# --> 566         return self.__rmul__(other)
#     567
#     568     ####################
#
# /usr/local/lib/python3.8/site-packages/scipy/sparse/base.py in __rmul__(self, other)
#     548             except AttributeError:
# ...

# %%
def repinner(xs):
    return np.hstack([x,x] for x in xs)
repinner([1,2])
# Out:
# array([1, 1, 2, 2])

# %%
plt.plot(repinner(ts)[1:-1],repinner(xs)[0:-2])
plt.xlabel("X")
plt.xlabel("t")
plt.yticks([0,1])
# Out:
# ([<matplotlib.axis.YTick at 0x11d0f19a0>,
# ...
#  [Text(0, 0, ''), Text(0, 0, '')])

# %%
Q
# Out:
# array([[-1,  1],
#        [ 2, -2]])
