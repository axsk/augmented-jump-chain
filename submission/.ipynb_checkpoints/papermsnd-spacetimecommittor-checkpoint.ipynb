# %%
# %autoreload 2
import sys
sys.path.append('src')
import sqra
import numpy as np
import ajc
import ajcs
from scipy.linalg import expm
import scipy.sparse.linalg as spl
import matplotlib.pyplot as plt

# %%
plt.set_cmap("bone_r")
#plt.set_cmap("afmhot_r")

# %%
class PaperPlots:
    def __init__(self, model):
        self.model = model
        self.Qs = model.Qs
        self.dt = np.array(model.dts)

        self.ajc = ajc.AJCGalerkin(np.dstack(self.Qs), self.dt)
        self.nt = np.size(self.Qs, 0)
        self.nx = np.size(self.Qs[0], 0)
    
    ######

    def jumpactivity(self, p0):
        return self.ajc.geiger(p0)

    def sync(self, p0):
        pp = self.jumpactivity(p0)
        return self.ajc.synchronize(pp)

    def kernelmatrix(self):
        return self.ajc.km

    def koopman_sync(self):
            k = np.zeros((self.nx, self.nx))
            for i in range(self.nx):
                x0 = np.zeros((self.nx, self.nt))
                x0[i,0] = 1
                k[i, :] = self.sync(x0)[:,-1]
            return k

    def koopman_q(self):
        k = np.identity(self.nx)
        for (i,t) in enumerate(self.dt):
            k = k @ expm(t * self.Qs[i])
        return k

    def koopman_error(self):
        ks = self.koopman_sync()
        kq = self.koopman_q()
        return np.linalg.norm(ks-kq, 2)

    #######

    def plot_transkernel(self):
        p = plt.imshow(self.kernelmatrix())

        cb = plt.colorbar()
        #cb.set_label("transition probability")
        plt.xticks()
        plt.yticks()
        plt.xlabel("X x T")
        plt.ylabel("X x T")
        return p

    def plot_jumpactivity(self, x0=0):
        p0 = np.zeros((self.nx,self.nt))
        p0[x0,0] = 1

        p = plt.imshow(self.jumpactivity(p0))

        #cb = plt.colorbar()
        #cb.set_label("jump activity")

        plt.ylabel("X")
        plt.xlabel("t")
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.xticks(np.arange(self.nt+1) -.5, np.hstack([0,np.cumsum(self.dt)]));
        return p

    def plot_sync(self, x0=0, p0=None):
        if p0 is None:
            p0 = np.zeros((self.nx,self.nt))
            p0[x0,0] = 1
        ps = self.sync(p0)

        p = plt.imshow(ps)

        #cb = plt.colorbar()
        #cb.set_label("probability (synchronized, one state)")

        plt.ylabel("X")
        plt.xlabel("t")
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.xticks(np.arange(self.nt+1) -.5, np.hstack([0,np.cumsum(self.dt)]));
        #plt.clim((0,1))
        return p

    def plot_koopman_sync(self):
        plt.imshow(self.koopman_sync())

        plt.xlabel("X")
        plt.ylabel("X")
        plt.xticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))

        cb = plt.colorbar()
        t2 = sum(self.dt)
        t1 = t2 - self.dt[-1]
        cb.set_label(f"probability (synchronized, t $\in  [{t1},{t2}]  $)")
        plt.clim((0,1))

    def plot_koopman_q(self):
        plt.imshow(self.koopman_q())
        plt.xlabel("X")
        plt.ylabel("X")

        plt.xticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))

        cb = plt.colorbar()
        t2 = sum(self.dt)
        cb.set_label(f"probability (exact, t={t2})")
        plt.clim((0,1))

    def plot_all(self, save=False):
        self.plot_transkernel()
        if save:
            plt.savefig(self.model.name() + "_transkernel.pdf")
        plt.show()

        self.plot_jumpactivity(0)
        if save:
            plt.savefig(self.model.name() + "_jumpactivity.pdf")
        plt.show()

        self.plot_sync(0)
        if save:
            plt.savefig(self.model.name() + "_sync.pdf")
        plt.show()

        self.plot_koopman_sync()
        if save:
            plt.savefig(self.model.name() + "_koopman_sync.pdf")
        plt.show()

        self.plot_koopman_q()
        if save:
            plt.savefig(self.model.name() + "_koopman_q.pdf")
        plt.show()

# %%
import scipy.sparse as sps

class PaperPlotsSparse(PaperPlots):
    def __init__(self, model):
        self.model = model
        self.Qs = model.Qs
        self.dt = np.array(model.dts)

        self.ajcs = ajcs.AJCS(self.Qs, self.dt)
        self.nt = np.size(self.Qs, 0)
        self.nx = np.size(self.Qs[0], 0)

    def jumpactivity(self, p0):
        return self.ajcs.geiger(p0.T).T

    def sync(self, p0):
        pp = self.jumpactivity(p0)
        return self.ajcs.synchronize(pp)

    def kernelmatrix(self):
        return  self.ajcs.km.toarray()

    def koopman_q(self):
        k = sps.identity(self.nx)
        for (i,t) in enumerate(self.dt):
            k = k @ spl.expm(t * self.Qs[i])
        return k

    def koopman_error(self):
        #ks = self.ajcs.koopman_system()
        ks = self.koopman_sync()
        kq = self.koopman_q()
        return np.linalg.norm(ks-kq, 2)

# %%
from copy import deepcopy

class ApproximationError:
    def __init__(self, model, nt = 10, tmax = 50):
        self.nts = np.ceil(np.logspace(0, np.log10(tmax), nt, base=10))
        self.nts = self.nts * 2
        self.models = []
        self.tmax = np.sum(model.dts)

        for nt in self.nts:
            m = deepcopy(model)
            m.nt = nt
            m.dt = self.tmax/nt
            print(m.dt)
            m._compute()
            self.models.append(m)
        
        self.errors = [PaperPlotsSparse(m).koopman_error() for m in self.models]
    
    def plot(self):
        nts = self.nts
        errors = self.errors
        plt.yscale("log")
        plt.xscale("log")
        p = plt.plot(self.tmax/nts, errors)
        plt.scatter(self.tmax/nts, errors)

        plt.xlabel(r'''step-size $\Delta T$''')        
        plt.ylabel(r'''error $\epsilon$''')
        plt.savefig("dwerror.png")
        return p

# %%
class DoubleWell:
    def __init__(self, nx = 5, ny = 1, xlims=(-1.5,1.5), ylims=(-1.5,1.5), dt=1, nt=4, beta=1):
        xs = np.linspace(*xlims, nx)
        ys = np.linspace(*ylims, ny)
        self.xs, self.ys = np.meshgrid(xs, ys, sparse=True)
        self.beta = beta

        self.nt = nt
        self.dt = dt
        self.nx = nx * ny
        self._compute()

    def _compute(self):
        self.dts = np.repeat(self.dt, self.nt)
        self.u = self.potential()
        self.sqra = sqra.Sqra(self.u, beta=self.beta)
        # use the commented version for dense computation
        #self.Qs = [self.sqra.Q.toarray()]*len(self.dt)
        self.Qs = [self.sqra.Q]*len(self.dts)
    
    def potential(self):
        return (self.xs**2-1)**2 + self.ys**2

    def name(self):
        return "dw"

# %%
class TripleWell(DoubleWell):
    def __init__(self, xlims=(-2, 2), ylims=(-1, 2), **kwargs):
        super().__init__(xlims=xlims, ylims=ylims, **kwargs)

    def potential(self):
        x = self.xs
        y = self.ys
        V = (3/4 * np.exp(-x**2 - (y-1/3)**2)
            - 3/4 * np.exp(-x**2 - (y-5/3)**2)
            - 5/4 * np.exp(-(x-1)**2 - y**2)
            - 5/4 * np.exp(-(x+1)**2 - y**2)
            + 1/20 * x**4 + 1/20 * (y-1/3)**4)
        return V

    def name(self):
        return "tw"

# %%
class TripleWellBeta(TripleWell):
    def __init__(self, beta1, beta2, **kwargs):
        self.beta1 = beta1
        self.beta2 = beta2
        
        super().__init__(**kwargs)

        assert self.nt % 2 == 0
        assert self.nt > 1

        
    def _compute(self):
        self.dts = np.repeat(self.dt, self.nt)
        self.u = self.potential()
        self.sqras = [sqra.Sqra(self.u, beta=self.beta1),
                      sqra.Sqra(self.u, beta=self.beta2)]
        # use the commented version for dense computation
        #self.Qs = [self.sqra.Q.toarray()]*len(self.dt)

        h = self.xs[0,1]-self.xs[0,0]
        #assert np.isclose(self.h, self.ys[1,0]-self.ys[0,0])
        nhalf = np.int(np.floor(self.nt/2))
        phi1 = 1 / (h*h*self.beta1)
        phi2 = 1 / (h*h*self.beta2)
        self.Qs = [phi1 * self.sqras[0].Q] * nhalf
        self.Qs = np.append(self.Qs, [phi2 * self.sqras[1].Q] * nhalf)

    def name(self):
        return "twb"

# %%
m=TripleWellBeta(1,10, nx=9, ny=7, nt=6, dt=.2)
mpaper=TripleWellBeta(1,10, nx=9, ny=7, nt=6, dt=1/3) # paper
mbig = TripleWellBeta(1,10, nx=18, ny=14, nt=6, dt=1/3)

m = mpaper
pb = PaperPlotsSparse(m)
# Out:
# /usr/local/lib/python3.9/site-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /usr/local/lib/python3.9/site-packages/scipy/sparse/_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
plt.set_cmap("bone_r")
#plt.set_cmap("afmhot_r")

pb.plot_transkernel()
plt.clim(0,0.1)
tx, lb = [i*pb.nx - .5 for i in range(7)], ["" if i%3 > 0 else f"t={np.int(i/3)}" for i in range(7)]
plt.xticks(tx,lb)
plt.yticks(tx,lb)
plt.grid(alpha=.5)
plt.savefig("ex2k.pdf", bbox_inches="tight")
plt.show()

# %%
ntot = np.prod(pb.kernelmatrix().shape)
nnz  = np.sum(pb.kernelmatrix() > 0)
ntot, nnz, nnz/ntot
# Out:
# (142884, 4620, 0.03233392122281011)

# %%
plt.spy(pb.kernelmatrix())
plt.xlabel("X x T")
plt.ylabel("X x T")
plt.xticks([])
plt.yticks([])
plt.savefig("ex2s.pdf", bbox_inches="tight")

# %%
ae = ApproximationError(m, tmax=100, nt=10)
# Out:
# 0.9999999999999999
# 0.49999999999999994
# 0.3333333333333333
# 0.19999999999999998
# 0.12499999999999999
# /usr/local/lib/python3.9/site-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /usr/local/lib/python3.9/site-packages/scipy/sparse/_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# 0.07692307692307691
# 0.04545454545454545
# 0.027777777777777776
# 0.016666666666666666
# 0.009999999999999998
# /usr/local/lib/python3.9/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:318: SparseEfficiencyWarning: splu requires CSC matrix format
#   warn('splu requires CSC matrix format', SparseEfficiencyWarning)
# /usr/local/lib/python3.9/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:215: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   warn('spsolve is more efficient when sparse b '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-5c426593d591> in <module>
# ----> 1 ae = ApproximationError(m, tmax=100, nt=10)
#
# <ipython-input-6-5e2060bb46a9> in __init__(self, model, nt, tmax)
#      16             self.models.append(m)
#      17
# ---> 18         self.errors = [PaperPlotsSparse(m).koopman_error() for m in self.models]
#      19
#      20     def plot(self):
#
# <ipython-input-6-5e2060bb46a9> in <listcomp>(.0)
#      16             self.models.append(m)
#      17
# ---> 18         self.errors = [PaperPlotsSparse(m).koopman_error() for m in self.models]
#      19
#      20     def plot(self):
#
# <ipython-input-5-fb79ac64cb3c> in koopman_error(self)
#      29     def koopman_error(self):
#      30         #ks = self.ajcs.koopman_system()
# ---> 31         ks = self.koopman_sync()
#      32         kq = self.koopman_q()
#      33         return np.linalg.norm(ks-kq, 2)
#
# <ipython-input-4-cee51b3a87e8> in koopman_sync(self)
#      26                 x0 = np.zeros((self.nx, self.nt))
#      27                 x0[i,0] = 1
# ---> 28                 k[i, :] = self.sync(x0)[:,-1]
#      29             return k
#      30
#
# <ipython-input-5-fb79ac64cb3c> in sync(self, p0)
#      15
#      16     def sync(self, p0):
# ---> 17         pp = self.jumpactivity(p0)
#      18         return self.ajcs.synchronize(pp)
#      19
#
# <ipython-input-5-fb79ac64cb3c> in jumpactivity(self, p0)
#      12
#      13     def jumpactivity(self, p0):
# ---> 14         return self.ajcs.geiger(p0.T).T
#      15
#      16     def sync(self, p0):
#
# ~/Documents/code/augjuc/submission/src/ajcs.py in geiger(self, p, n)
#      89         pp = p
#      90         for i in range(n):
# ---> 91             pp = self.jump(pp)
#      92             g = g + pp
#      93         return g
#
# ~/Documents/code/augjuc/submission/src/ajcs.py in jump(self, p)
#      83     # TODO: compute this without falling back to the kernel matrix
#      84     def jump(self, p):
# ---> 85         return np.reshape(p.flatten() @ self.km, p.shape)
#      86
#      87     def geiger(self, p, n=100):
#
# ~/Documents/code/augjuc/submission/src/ajcs.py in km(self)
#      78     def km(self):
#      79         if not hasattr(self, "_km"):
# ---> 80             self._km = flatten_spacetime(self.k) # TODO: find a good way to deal with differing representations
#      81         return self._km
#      82
#
# ~/Documents/code/augjuc/submission/src/ajcs.py in flatten_spacetime(tensor)
#     240                 row = tensor[s, t]
#     241             else:
# --> 242                 row = sp.hstack((row, tensor[s, t]))
#     243         if s == 0:
#     244             M = row
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/construct.py in hstack(blocks, format, dtype)
#     465
#     466     """
# --> 467     return bmat([blocks], format=format, dtype=dtype)
#     468
#     469
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/construct.py in bmat(blocks, format, dtype)
#     574         for j in range(N):
#     575             if blocks[i,j] is not None:
# --> 576                 A = coo_matrix(blocks[i,j])
#     577                 blocks[i,j] = A
#     578                 block_mask[i,j] = True
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/coo.py in __init__(self, arg1, shape, dtype, copy)
#     194             self.data = self.data.astype(dtype, copy=False)
#     195
# --> 196         self._check()
#     197
#     198     def reshape(self, *args, **kwargs):
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/coo.py in _check(self)
#     280
#     281         if self.nnz > 0:
# --> 282             if self.row.max() >= self.shape[0]:
#     283                 raise ValueError('row index exceeds matrix dimensions')
#     284             if self.col.max() >= self.shape[1]:
#
# /usr/local/lib/python3.9/site-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      37 def _amax(a, axis=None, out=None, keepdims=False,
#      38           initial=_NoValue, where=True):
# ---> 39     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      40
#      41 def _amin(a, axis=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
size=3
plt.figure(figsize=(3*1.618,3))
plt.rc('text', usetex=True)
ae.plot()
plt.grid(which="major",alpha=.3)
plt.savefig("tw_error.pdf", bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-607766a86143> in <module>
#       2 plt.figure(figsize=(3*1.618,3))
#       3 plt.rc('text', usetex=True)
# ----> 4 ae.plot()
#       5 plt.grid(which="major",alpha=.3)
#       6 plt.savefig("tw_error.pdf", bbox_inches="tight")
#
# NameError: name 'ae' is not defined

# %% [markdown]
# p0 = np.zeros((m.nx, m.nt))
# p0[:,0] = 1 / m.nx
# pb.plot_sync(0, p0)

# %% [markdown]
# d = DoubleWell(nx=20)
# d = DoubleWell(nx=5, xlims=(-2,2),dt=1, nt=5)
# t = TripleWell(nx=10, ny=8, nt=10)
#
# model = t

# %%
class TwoGraph:
    def __init__(self, nt = 2, dt=1):
        q1 = 1
        q0 = 1e-6
        self.Q1 = np.array([[-q1,q1],[q0,-q0]])
        self.Q2 = np.array([[-q0, q0],[q1,-q1]])
        self.nx = 2
        self.nt = nt
        self.Qs = np.zeros((self.nx,self.nx,self.nt))
        
        for i in range(nt):
            self.Qs[:,:,i] = self.Q1 if i/nt < .5 else self.Q2

        self.Qs = [self.Q1 if i/nt < .5 else self.Q2 for i in range(nt)]

        self.dts = [dt]*nt
        #self.dts[0] = 1e-5
        #self.dts[-1] = 1e-5

    def name(self):
        return "twograph"

# %%
class SingleQ:
    def __init__(self, Q, nt = 2, dt=1):
        self.Qs = [Q for i in range(nt)]
        self.dts = [dt]*nt
        self.nx = np.size(Q,0)
        self.nt = nt
        self.x0 = np.zeros((nt, self.nx))
        self.x0[0,0] = 1
    
    def name(self):
        return "simpleq"

Q =  np.array([[-2,1,1],[1,-2,1],[1, 0, -1]])
qm = SingleQ(Q, nt=10, dt=.2)
pqm = PaperPlots(qm)

# %%
pqm.plot_all(save=True)

# %%
p = plt.imshow(qm.x0.T)
self = pqm
#cb = plt.colorbar()
#cb.set_label("jump activity")

plt.ylabel("X")
plt.xlabel("t")
plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
plt.xticks(np.arange(self.nt+1)[[0,-1]] -.5, np.hstack([0,np.cumsum(self.dt)])[[0,-1]]);
plt.savefig("slides/x0.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-2b70e4a69025> in <module>
#       8 plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
#       9 plt.xticks(np.arange(self.nt+1)[[0,-1]] -.5, np.hstack([0,np.cumsum(self.dt)])[[0,-1]]);
# ---> 10 plt.savefig("slides/x0.pdf")
#
# /usr/local/lib/python3.9/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# /usr/local/lib/python3.9/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /usr/local/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# /usr/local/lib/python3.9/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2584             file = filename._file
#    2585         else:
# -> 2586             file = PdfFile(filename, metadata=metadata)
#    2587         try:
#    2588             file.newPage(width, height)
#
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     560         self.original_file_like = None
#     561         self.tell_base = 0
# --> 562         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     563         if not opened:
#     564             try:
#
# /usr/local/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     406             fh = bz2.BZ2File(fname, flag)
#     407         else:
# --> 408             fh = open(fname, flag, encoding=encoding)
#     409         opened = True
#     410     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'slides/x0.pdf'

# %%
jx0 = pqm.ajc.jump(qm.x0.T)
p = plt.imshow(jx0)
self = pqm
#cb = plt.colorbar()
#cb.set_label("jump activity")

plt.ylabel("X")
plt.xlabel("t")
plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
plt.xticks(np.arange(self.nt+1)[[0,-1]] -.5, np.hstack([0,np.cumsum(self.dt)])[[0,-1]]);
plt.savefig("slides/jx0.pdf")

# %%
jx1 = pqm.ajc.jump(jx0)
p = plt.imshow(jx1)
self = pqm
#cb = plt.colorbar()
#cb.set_label("jump activity")

plt.ylabel("X")
plt.xlabel("t")
plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
plt.xticks(np.arange(self.nt+1)[[0,-1]] -.5, np.hstack([0,np.cumsum(self.dt)])[[0,-1]]);
plt.savefig("slides/jx1.pdf")

# %%
plt.set_cmap("bone_r")
#plt.set_cmap("afmhot_r")

g = TwoGraph(nt=8, dt=1)
PaperPlots(g).plot_all(save=True)

# %%
pg = PaperPlots(g)
p = plt.imshow(pg.kernelmatrix(), interpolation="nearest")

cb = plt.colorbar()
plt.xticks([], labels=None)
tx, lb = [i*2 - .5 for i in range(9)], ["" if i%4 > 0 else f"t={i}" for i in range(9)]
plt.xticks(tx,lb)
plt.yticks(np.array(tx)-0.05, lb)
plt.grid(alpha=.4)
plt.xlabel("X x T")
plt.ylabel("X x T")
plt.savefig("ex1k.pdf", bbox_inches="tight")

# %%
p = pg.plot_jumpactivity()
plt.clim(0,1)
plt.savefig("ex1a.pdf")

# %%
def evolutionplots(self):
        x0 = 0
        p0 = np.zeros((self.nx,self.nt))
        p0[x0,0] = 1

        ax1 = plt.subplot(211)

        

        p = plt.imshow(self.jumpactivity(p0))
        plt.clim(0,1)
        #cb = plt.colorbar()
        #cb.set_label("jump activity")

        plt.ylabel("X")

        #plt.xlabel("t")
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
        
        plt.xticks(np.arange(self.nt+1) -.5, np.hstack([0,np.cumsum(self.dt)]));
        plt.yticks([0,1],["A","B"])
        plt.xticks([])

        ps = self.sync(p0)
        ax2 = plt.subplot(212)

        p = plt.imshow(ps)
        plt.clim(0,1)
        #cb = plt.colorbar()
        #cb.set_label("probability (synchronized, one state)")

        plt.ylabel("X")
        plt.xlabel("T")
        plt.yticks(np.arange(self.nx), np.arange(1,self.nx+1))
        plt.xticks(np.arange(self.nt+1) -.5, np.hstack([0,np.cumsum(self.dt)]));
        plt.yticks([0,1],["A","B"])
        #plt.subplots_adjust(hspace=0.8)

        plt.colorbar(ax = [ax1, ax2], location="top", shrink=0.94, ticks=[0,1], anchor=(0.5,0.6))

evolutionplots(pg)
plt.savefig("ex1ev.pdf", bbox_inches="tight")

# %%
p = pg.plot_sync()
plt.clim(0,1)
plt.colorbar(orientation="horizontal")
plt.savefig("ex1s.pdf")

# %%
ae.nts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-7b91ba916c89> in <module>
# ----> 1 ae.nts
#
# NameError: name 'ae' is not defined

# %%
b2=TripleWellBeta(1,10, nx=18, ny=14, nt=6, dt=.2)
ae2 = ApproximationError(b2, tmax=50, nt=5)
# Out:
# /usr/local/lib/python3.9/site-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /usr/local/lib/python3.9/site-packages/scipy/sparse/_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# 0.6
# 0.19999999999999998
# 0.075
# 0.031578947368421054
# 0.012
# /usr/local/lib/python3.9/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:318: SparseEfficiencyWarning: splu requires CSC matrix format
#   warn('splu requires CSC matrix format', SparseEfficiencyWarning)
# /usr/local/lib/python3.9/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:215: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   warn('spsolve is more efficient when sparse b '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-0fa539d11f2a> in <module>
#       1 b2=TripleWellBeta(1,10, nx=18, ny=14, nt=6, dt=.2)
# ----> 2 ae2 = ApproximationError(b2, tmax=50, nt=5)
#
# <ipython-input-6-5e2060bb46a9> in __init__(self, model, nt, tmax)
#      16             self.models.append(m)
#      17
# ---> 18         self.errors = [PaperPlotsSparse(m).koopman_error() for m in self.models]
#      19
#      20     def plot(self):
#
# <ipython-input-6-5e2060bb46a9> in <listcomp>(.0)
#      16             self.models.append(m)
#      17
# ---> 18         self.errors = [PaperPlotsSparse(m).koopman_error() for m in self.models]
#      19
#      20     def plot(self):
#
# <ipython-input-5-fb79ac64cb3c> in koopman_error(self)
#      29     def koopman_error(self):
#      30         #ks = self.ajcs.koopman_system()
# ---> 31         ks = self.koopman_sync()
#      32         kq = self.koopman_q()
#      33         return np.linalg.norm(ks-kq, 2)
#
# <ipython-input-4-cee51b3a87e8> in koopman_sync(self)
#      26                 x0 = np.zeros((self.nx, self.nt))
#      27                 x0[i,0] = 1
# ---> 28                 k[i, :] = self.sync(x0)[:,-1]
#      29             return k
#      30
#
# <ipython-input-5-fb79ac64cb3c> in sync(self, p0)
#      15
#      16     def sync(self, p0):
# ---> 17         pp = self.jumpactivity(p0)
#      18         return self.ajcs.synchronize(pp)
#      19
#
# <ipython-input-5-fb79ac64cb3c> in jumpactivity(self, p0)
#      12
#      13     def jumpactivity(self, p0):
# ---> 14         return self.ajcs.geiger(p0.T).T
#      15
#      16     def sync(self, p0):
#
# ~/Documents/code/augjuc/submission/src/ajcs.py in geiger(self, p, n)
#      89         pp = p
#      90         for i in range(n):
# ---> 91             pp = self.jump(pp)
#      92             g = g + pp
#      93         return g
#
# ~/Documents/code/augjuc/submission/src/ajcs.py in jump(self, p)
#      83     # TODO: compute this without falling back to the kernel matrix
#      84     def jump(self, p):
# ---> 85         return np.reshape(p.flatten() @ self.km, p.shape)
#      86
#      87     def geiger(self, p, n=100):
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/base.py in __rmatmul__(self, other)
#     564             raise ValueError("Scalar operands are not allowed, "
#     565                              "use '*' instead")
# --> 566         return self.__rmul__(other)
#     567
#     568     ####################
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/base.py in __rmul__(self, other)
#     548             except AttributeError:
#     549                 tr = np.asarray(other).transpose()
# --> 550             return (self.transpose() * tr).transpose()
#     551
#     552     #######################
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/coo.py in transpose(self, axes, copy)
#     296
#     297         M, N = self.shape
# --> 298         return coo_matrix((self.data, (self.col, self.row)),
#     299                           shape=(N, M), copy=copy)
#     300
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/coo.py in __init__(self, arg1, shape, dtype, copy)
#     194             self.data = self.data.astype(dtype, copy=False)
#     195
# --> 196         self._check()
#     197
#     198     def reshape(self, *args, **kwargs):
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/coo.py in _check(self)
#     274                     % self.col.dtype.name)
#     275
# --> 276         idx_dtype = get_index_dtype(maxval=max(self.shape))
#     277         self.row = np.asarray(self.row, dtype=idx_dtype)
#     278         self.col = np.asarray(self.col, dtype=idx_dtype)
#
# /usr/local/lib/python3.9/site-packages/scipy/sparse/sputils.py in get_index_dtype(arrays, maxval, check_contents)
#     139     """
#     140
# --> 141     int32min = np.iinfo(np.int32).min
#     142     int32max = np.iinfo(np.int32).max
#     143
#
# /usr/local/lib/python3.9/site-packages/numpy/core/getlimits.py in min(self)
#     507             raise ValueError("Invalid integer data type %r." % (self.kind,))
#     508
# --> 509     @property
#     510     def min(self):
#     511         """Minimum value of given dtype."""
#
# KeyboardInterrupt:

# %%
ae.plot()
ae2.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-baf3a82c4999> in <module>
# ----> 1 ae.plot()
#       2 ae2.plot()
#
# NameError: name 'ae' is not defined

# %%
x=np.vstack(np.array(expm(t*m.Qs[1]).todense())[:,0].reshape(-1) for t in np.arange(0,1,0.01))
# Out:
# <ipython-input-36-3ec657e86cd3>:1: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   x=np.vstack(np.array(expm(t*m.Qs[1]).todense())[:,0].reshape(-1) for t in np.arange(0,1,0.01))

# %%
plt.plot(x)
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
x
