# %%
# %autoreload 2

# %%
import ajc
import ajcs
from  copy import deepcopy
import matplotlib.pyplot as plt
import numpy as np
import scipy.sparse as sp

# %%
nx = 40
nt = 10
Qs = [sp.random(nx,nx, 0.5) for i in range(nt)]
dts = np.array([1 for i in range(nt)])

# %%
Qs[0]
# Out:
# <40x40 sparse matrix of type '<class 'numpy.float64'>'
# 	with 800 stored elements in COOrdinate format>

# %%
Qsd = np.array([Q.todense() for Q in Qs])
Qsd = np.moveaxis(Qsd, 0, 2)
jj = ajc.AJCGalerkin(Qsd, dts)

# %%
j = ajcs.AJCS(Qs, dts)

# %%
q = j.finite_time_hitting_prob(1)

# %%
plt.imshow(q)

# %%
plt.imshow(ajcs.flatten_spacetime(j.k).todense())

# %%
hps= [j.finite_time_hitting_prob(i) for i in range(nx)]

# %%
hpp=([h[0] for h in hps])

# %%
obj(hps) = min([hps[i][0,0] for i in range(nx)])
# Out:
#   File "<ipython-input-12-55236ce2bb96>", line 1
#     obj(hps) = min([hps[i][0,0] for i in range(nx)])
#     ^
# SyntaxError: cannot assign to function call
